# %% [markdown]
# 1. One Dimensional Array
# A one-dimensional array is a type of linear array.

# %%
import numpy as np
a =[1,2,3,4,5]
arr = np.array(a)

print("List in Python: ", a)
print("NumPy Array in Python: ", arr)
print("Type of List:", type(a))
print("Type of NumPy Array:", type(arr))
# Out:
# List in Python:  [1, 2, 3, 4, 5]
# NumPy Array in Python:  [1 2 3 4 5]
# Type of List: <class 'list'>
# Type of NumPy Array: <class 'numpy.ndarray'>

# %% [markdown]
# 2. Multi-Dimensional Array
# A Multi-Dimensional Array is an array that can store data in more than one dimension such as rows and columns. In simple terms it is a array of arrays.
#
# For example a 2D array is like a table with rows and columns where each element is accessed by two indices: one for the row and one for the column. Higher dimensions like 3D arrays involve adding additional layers.

# %%
list1 = [1,2,3]
list2 = [4,5,6]
list3 = [7,8,9]

multi_Dim_array = np.array([list1,
                            list2,
                            list3])

print("This Multidimentional Array: \n", multi_Dim_array)
# Out:
# This Multidimentional Array:
#  [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %% [markdown]
# Parameters of a Numpy Array
#
# 1. Axis: Axis of an array describes the order of the indexing into the array.
# Axis 0 = one dimensional   --> operate vertically/down rows
# Axis 1 = Two dimensional   --> operate horizontally/across columns
# Axis 2 = Three dimensional
#
# Axis represents the direction along which an operation is performed in a multidimensional array.
# Axis 0 operates vertically across rows, Axis 1 horizontally across columns in 2D arrays.

# %%
arr = [
 [1, 2, 3],
 [4, 5, 6]
]
print(np.sum(arr, axis=0)) #[5(1+4) 7(2+5) 9(6+3)]
print(np.sum(arr, axis=1)) #[6(1+2+3) 15(4+5+6)]
# Out:
# [5 7 9]
# [ 6 15]

# %%
#2. Shape: Number of elements along with each axis and is returned as a tuple.

numPy_array = np.array([[1,2,3,1],
                        [2,6,7,2],
                        [3,6,7,3],
                        [4,6,7,4],
                        [5,6,7,5],])
print("Shape of the Array: ", numPy_array.shape)
# Out:
# Shape of the Array:  (5, 4)

# %% [markdown]
# 4. Data type objects (dtype): Data type objects (dtype) is an example of numpy.dtype class. It describes how the bytes in the fixed-size block of memory corresponding to an array item should be interpreted.

# %%
array1 = np.array([1,2,3])
array2 = np.array([2.3, 5.6, 11])
array3 = np.array(["a", "b"])

print(array1.dtype)
print(array2.dtype)
print(array3.dtype)
# Out:
# int64
# float64
# <U1

# %% [markdown]
# **# Different Ways of Creating Numpy Array**

# %%
#1. numpy.array(): Numpy array object in Numpy is called ndarray. We can create ndarray using this function.
#Syntax: np.array(parameter)
arr1 = np.array([1,2,3,4,5])
print("Method 1: ", arr1)


#2. numpy.fromiter(): The fromiter() function create a new one-dimensional array from an iterable object.
# Syntax: np.fromiter(iterable, dtype, count=-1)
var = "NitinPatil"
arr2 = np.fromiter(var, dtype='U2')
print("Method 2: ", arr2)

#3. numpy.arange(): This is an inbuilt NumPy function that returns evenly spaced values within a given interval.
# Syntax:  numpy.arange( start , stop, step , dtype=None )
arr3 = np.arange(3, 22, 3, dtype= np.float32)
print("Method 3: ", arr3)

#4. numpy.linspace(): This function returns evenly spaced numbers over a specified between two limits. 
# Syntax: numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)

arr4 = np.empty([4, 3],
         dtype = np.int32,
         order = 'f')
print("Method 4: \n", arr4)

#6. numpy.ones(): This function is used to get a new array of given shape and type filled with ones (1).
# Syntax: numpy.ones(shape, dtype=None, order='C')
arr5 = np.ones([3,3], )
print("Method 5: \n", arr5)

#7. numpy.zeros(): This function is used to get a new array of given shape and type filled with zeros (0). 
#Syntax: numpy.zeros(shape, dtype=None, order='C')
arr6 = np.zeros([3,3], )
print("Method 6: \n", arr6)
# Out:
# Method 1:  [1 2 3 4 5]
# Method 2:  ['N' 'i' 't' 'i' 'n' 'P' 'a' 't' 'i' 'l']
# Method 3:  [ 3.  6.  9. 12. 15. 18. 21.]
# Method 4:
#  [[        -1          0          0]
#  [2146435071 1073741824    1048576]
#  [        -1          0          1]
#  [  -1048577 1018167296          0]]
# Method 5:
#  [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]
# Method 6:
#  [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
a0 = np.zeros((2, 3))
a1 = np.ones((3, 3))
af = np.full((2, 2), 7)
ar = np.arange(0, 10, 2)  # start, stop, step
la = np.linspace(0, 1, 5)  # start, stop, num

print("Zero Array:","\n",a0)
print("Ones Array:","\n",a1)
print("Constant Array:","\n",af)
print("Range Array:","\n",ar)
print("Linspace Array:","\n",la)
# Out:
# Zero Array:
#  [[0. 0. 0.]
#  [0. 0. 0.]]
# Ones Array:
#  [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]
# Constant Array:
#  [[7 7]
#  [7 7]]
# Range Array:
#  [0 2 4 6 8]
# Linspace Array:
#  [0.   0.25 0.5  0.75 1.  ]
